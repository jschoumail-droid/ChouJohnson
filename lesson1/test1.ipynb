# %%
print('Hello')
# Out:
# Running cells with 'd:\Python\Install\Python3.10.8\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'd:/Python/Install/Python3.10.8/python.exe -m pip install ipykernel -U --user --force-reinstall'
